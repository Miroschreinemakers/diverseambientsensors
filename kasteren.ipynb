# %%
# %run cnn_next_action_prediction.py
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Currently logged in as: miroschreinemakers. Use `wandb login --relogin` to force relogin
# wandb version 0.16.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/Users/miro/Documents/ARAS/activity_segmentation_copy_2_test/next_action_prediction/wandb/run-20240224_223939-mtxsq75t</code>
# Syncing run <strong><a href='https://wandb.ai/miroschreinemakers/har_futuraal/runs/mtxsq75t' target="_blank">dauntless-donkey-55</a></strong> to <a href='https://wandb.ai/miroschreinemakers/har_futuraal' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...
